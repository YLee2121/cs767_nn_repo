# %%
import sys
sys.path.append('./src/')
from helper import *
import warnings
warnings.filterwarnings('ignore')
import time

# %% [markdown]
# # Problem 1

# %%
# dataset
from sklearn.datasets import load_breast_cancer, load_iris, load_wine
cancer = load_breast_cancer()
iris = load_iris()
wine = load_wine()

df1 = pd.DataFrame(data = cancer.data, columns=cancer.feature_names)
df1['target'] = cancer.target

df2 = pd.DataFrame(data=iris.data, columns=iris.feature_names)
df2['target'] = iris.target

df3 = pd.DataFrame(data=wine.data, columns=wine.feature_names)
df3['target'] = wine.target

# %% [markdown]
# # Problem2

# %%
# df1 (housing)
display(df1.head())

# print the accuracy
foo1(df1)
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# ...

# %%
# df2 (iris)
display(df2.head())

# print the accuracy
foo1(df2)
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
# tree cart accracy 0.978
# knn accuracy 0.978
# svm accuracy 0.978
# NB accuracy 1.000
# tree ID3 accuracy 0.978
#
# 10 FOLD
# tree cart accracy 0.960
# knn accuracy 0.967
# svm accuracy 0.973
# NB accuracy 0.953
# tree ID3 accuracy 0.927

# %%
# df3 (wine)
display(df3.head())

# print the accuracy
foo1(df3)
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline  target
# ...

# %% [markdown]
# # Problem 3

# %% [markdown]
# ### DF2 IRIS AUGMENTATION

# %%
# df2 (iris) augmentation
df2[df2.target==0].describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count           50.00000         50.000000          50.000000
# mean             5.00600          3.428000           1.462000
# std              0.35249          0.379064           0.173664
# min              4.30000          2.300000           1.000000
# 25%              4.80000          3.200000           1.400000
# 50%              5.00000          3.400000           1.500000
# 75%              5.20000          3.675000           1.575000
# max              5.80000          4.400000           1.900000
#
#        petal width (cm)  target
# count         50.000000    50.0
# mean           0.246000     0.0
# std            0.105386     0.0
# min            0.100000     0.0
# 25%            0.200000     0.0
# 50%            0.200000     0.0
# 75%            0.300000     0.0
# max            0.600000     0.0

# %%
df2[df2.target==1].describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count          50.000000         50.000000          50.000000
# mean            5.936000          2.770000           4.260000
# std             0.516171          0.313798           0.469911
# min             4.900000          2.000000           3.000000
# 25%             5.600000          2.525000           4.000000
# 50%             5.900000          2.800000           4.350000
# 75%             6.300000          3.000000           4.600000
# max             7.000000          3.400000           5.100000
#
#        petal width (cm)  target
# count         50.000000    50.0
# mean           1.326000     1.0
# std            0.197753     0.0
# min            1.000000     1.0
# 25%            1.200000     1.0
# 50%            1.300000     1.0
# 75%            1.500000     1.0
# max            1.800000     1.0

# %%
df2[df2.target==2].describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count           50.00000         50.000000          50.000000
# mean             6.58800          2.974000           5.552000
# std              0.63588          0.322497           0.551895
# min              4.90000          2.200000           4.500000
# 25%              6.22500          2.800000           5.100000
# 50%              6.50000          3.000000           5.550000
# 75%              6.90000          3.175000           5.875000
# max              7.90000          3.800000           6.900000
#
#        petal width (cm)  target
# count          50.00000    50.0
# mean            2.02600     2.0
# std             0.27465     0.0
# min             1.40000     2.0
# 25%             1.80000     2.0
# 50%             2.00000     2.0
# 75%             2.30000     2.0
# max             2.50000     2.0

# %%
# augment data 
# d1 original
d1 = pd.DataFrame(df2) 
n = len(d1)

# d2 x1
d2 = pd.DataFrame(d1)
new_df = sample_df_for_iris(n//3)
d2 = pd.concat([d2, new_df])
d2 = d2.reset_index(drop=True)

# d3 x2
d3 = pd.DataFrame(d2)
new_df = sample_df_for_iris(n//3)
d3 = pd.concat([d3, new_df])
d3 = d3.reset_index(drop=True)


# d3 x3 
d4 = pd.DataFrame(d3)
new_df = sample_df_for_iris(n//3)
d4 = pd.concat([d4, new_df])
d4 = d4.reset_index(drop=True)

# d5 x4
d5 = pd.DataFrame(d4)
new_df = sample_df_for_iris(n//3)
d5 = pd.concat([d5, new_df])
d5 = d5.reset_index(drop=True)

# %% [markdown]
# # Problem 4

# %%
# XGBoost
start_time = time.time()
for df in [d1, d2, d3, d4, d5]:
    tmp = xgboost_accuracy(df)
    print(tmp)
print('time')
print(time.time() - start_time)
# Out:
# 0.9777777777777777
# 0.9444444444444444
# 0.9629629629629629
# 0.9777777777777777
# 0.9866666666666667
# time
# 0.46387600898742676

# %%
# CATBoost
start_time = time.time()
for df in [d1, d2, d3, d4, d5]:
    tmp = catboost_accuracy(df)
    print(tmp)
print('time')
print(time.time() - start_time)
# Out:
# 0.9777777777777777
# 0.9444444444444444
# 0.9555555555555556
# 0.9722222222222222
# 0.9866666666666667
# time
# 7.876206636428833

# %%
# LightGBM
start_time = time.time()
for df in [d1, d2, d3, d4, d5]:
    tmp = lgbm_accuracy(df)
    print(tmp)
print('time')
print(time.time() - start_time)
# Out:
# 0.9555555555555556
# 0.9444444444444444
# 0.9629629629629629
# 0.9833333333333333
# 0.9866666666666667
# time
# 0.5395140647888184
